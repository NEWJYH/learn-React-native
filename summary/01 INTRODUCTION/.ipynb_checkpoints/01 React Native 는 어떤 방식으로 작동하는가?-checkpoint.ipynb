# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #
#
# ---
#
# #

# %% [markdown]
# # 01 React Native가 무엇인가?

# %% [markdown]
#  - Browser가 내장 된 것이 아님
#
#  - React Native는 인터페이스로
#
#    우리와 운영 체제(ios, 안드로이드) 사이에 있음
#
#
# ![image.png](attachment:image.png)
#
#  - 코드는 ios 또는 Java 안드로이드 코드로 번역 되는 것

# %% [markdown]
# #
#
# ---
#
# #

# %% [markdown]
# # 02 어떻게 작동하는가?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 우리는 Bridge에 관한 어떤 코드도 작성하지 않을 것
#
# - JavaScript 부분 코드만 작성하게 될 유일한 부분
# ![image.png](attachment:image.png)
